# %% [markdown]
# <a href="https://colab.research.google.com/github/libertymdz/libertymdz/blob/main/colabnotebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This is my **first *Google* Colab **doc**![LibertyM.jpg](data:image/jpeg;base64,...)

# %%
1+1
# Out:
# 2

# %% [markdown]
# # This is my first colab **notebook**
